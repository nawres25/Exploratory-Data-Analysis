# %% [markdown]
# Goal : As a business manager, try to find out the weak areas where you can work to make more profit.

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# DATA ANALYSIS

# %%
data = pd.read_csv("SampleSuperstore.csv")
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# We can drop the country column because it's redundant since we have only the United States
data.drop(['Country'],axis=1)
# Out:
#            Ship Mode    Segment             City       State  Postal Code  \
# 0       Second Class   Consumer        Henderson    Kentucky        42420
# 1       Second Class   Consumer        Henderson    Kentucky        42420
# 2       Second Class  Corporate      Los Angeles  California        90036
# 3     Standard Class   Consumer  Fort Lauderdale     Florida        33311
# 4     Standard Class   Consumer  Fort Lauderdale     Florida        33311
# ...              ...        ...              ...         ...          ...
# 9989    Second Class   Consumer            Miami     Florida        33180
# 9990  Standard Class   Consumer       Costa Mesa  California        92627
# 9991  Standard Class   Consumer       Costa Mesa  California        92627
# 9992  Standard Class   Consumer       Costa Mesa  California        92627
# 9993    Second Class   Consumer      Westminster  California        92683
#
#      Region         Category Sub-Category     Sales  Quantity  Discount  \
# ...

# %% [markdown]
# Effect of Ship Mode and Segment on Profit

# %%
fig = plt.figure(figsize=(8,5))
ship=data.groupby('Ship Mode').mean().reset_index()
plt.bar(ship['Ship Mode'],ship['Profit'],width=0.5)
plt.title('Profit for each ship mode')
plt.show()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\2296234688.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ship=data.groupby('Ship Mode').mean().reset_index()

# %%
ship
# Out:
#         Ship Mode   Postal Code       Sales  Quantity  Discount     Profit
# 0     First Class  54765.611834  228.497024  3.701560  0.164610  31.839948
# 1        Same Day  57536.082873  236.396179  3.609576  0.152394  29.266591
# 2    Second Class  55626.009254  236.089239  3.816452  0.138895  29.535545
# 3  Standard Class  54944.447051  227.583067  3.819873  0.160023  27.494770

# %%
fig = plt.figure(figsize=(8,5))
ship=data.groupby('Segment').mean().reset_index()
plt.bar(ship['Segment'],ship['Profit'],width=0.5)
plt.title('Profit for each Segment')
plt.show()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\2777278714.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ship=data.groupby('Segment').mean().reset_index()

# %%
ship
# Out:
#        Segment   Postal Code       Sales  Quantity  Discount     Profit
# 0     Consumer  55649.895781  223.733644  3.760547  0.158141  25.836873
# 1    Corporate  54482.228477  233.823300  3.843709  0.158228  30.456667
# 2  Home Office  55051.998317  240.972041  3.782389  0.147128  33.818664

# %% [markdown]
# The results for the Ship Mode are quite similar so we can make conclusion on its effect on the profit,as for the segment,Home Office has the highest profit followed by Corporate and Consumer.

# %% [markdown]
# Effect of the region on the Profit

# %%
fig = plt.figure(figsize=(8,5))
ship=data.groupby('Region').mean().reset_index()
plt.bar(ship['Region'],ship['Profit'],width=0.5)
plt.title('Profit for each Segment')
plt.show()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\506390845.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ship=data.groupby('Region').mean().reset_index()

# %%
ship
# Out:
#     Region   Postal Code       Sales  Quantity  Discount     Profit
# 0  Central  65340.572536  215.772661  3.779595  0.240353  17.092709
# 1     East  17616.466994  238.336110  3.728230  0.145365  32.135808
# 2    South  34490.772840  241.803645  3.832716  0.147253  28.857673
# 3     West  91707.696534  226.493233  3.829535  0.109335  33.849032

# %% [markdown]
# There are not much discrepencies region wise other than a lower overall profit in the central region.

# %%
data.groupby(['Region','Category']).mean()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\538030006.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Region','Category']).mean()
#                           Postal Code       Sales  Quantity  Discount  \
# Region  Category
# Central Furniture        65486.453222  340.534644  3.798337  0.297380
#         Office Supplies  65275.734880  117.458801  3.803797  0.252743
#         Technology       65393.026190  405.753124  3.676190  0.133095
# East    Furniture        17317.247920  346.574383  3.683860  0.154077
#         Office Supplies  17401.548481  120.044425  3.774533  0.142932
#         Technology       18640.338318  495.278469  3.629907  0.143364
# South   Furniture        34552.117470  353.309289  3.888554  0.121536
# ...

# %% [markdown]
#  If we look at how each sector performs, we can conclude that the central region should improve in the Furniture and Office Supplies sections .

# %% [markdown]
# The TOP 10 States in terms of Profit

# %%
fig=plt.figure(figsize=(10,8))
state=data.groupby(['State']).mean().reset_index().sort_values(by='Profit',ascending=False).head(10)
plt.bar(state['State'],state['Profit'],width=0.25,color='red')
plt.xticks(rotation=45)
plt.title('Profit for each state')
plt.show()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\2914098178.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   state=data.groupby(['State']).mean().reset_index().sort_values(by='Profit',ascending=False).head(10)

# %%
state
# Out:
#                    State   Postal Code        Sales  Quantity  Discount  \
# 43               Vermont   5408.000000   811.760909  4.545455  0.000000
# 37          Rhode Island   2908.535714   404.070643  3.553571  0.021429
# 12               Indiana  46923.503356   359.431946  3.879195  0.000000
# 24               Montana  59491.733333   372.623467  3.733333  0.066667
# 21             Minnesota  55418.247191   335.541011  3.719101  0.000000
# 7   District of Columbia  20016.000000   286.502000  4.000000  0.000000
# 6               Delaware  19755.250000   285.948635  3.822917  0.006250
# 48               Wyoming  82001.000000  1603.136000  4.000000  0.200000
# 23              Missouri  65126.696970   336.441667  3.818182  0.000000
# 20              Michigan  48455.305882   299.096525  3.709804  0.007059
#
#         Profit
# 43  204.088936
# 37  130.100523
# 12  123.375411
# 24  122.221900
# 21  121.608847
# 7   105.958930
# 6   103.930988
# 48  100.196000
# 23   97.518341
# ...

# %% [markdown]
# Effect of each category on the Profit

# %%
fig=plt.figure(figsize=(10,8))
category=data.groupby(['Category']).mean().reset_index()
plt.pie(category['Profit'],autopct='%1.2f%%',explode=(0.08,0.04,0.06),colors=('blue','green','red'))
plt.legend(category['Category'])
plt.title('Profit Made in each Category')
plt.show()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\934260907.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   category=data.groupby(['Category']).mean().reset_index()

# %%
category
# Out:
#           Category   Postal Code       Sales  Quantity  Discount     Profit
# 0        Furniture  55726.556341  349.834887  3.785007  0.173923   8.699327
# 1  Office Supplies  54890.951211  119.324101  3.801195  0.157285  20.327050
# 2       Technology  55551.572279  452.709276  3.756903  0.132323  78.752002

# %% [markdown]
#  Top 10 Profits

# %%
data.sort_values(by='Profit').tail(10)
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 6520    Second Class     Consumer  United States        Jackson      Michigan
# 7666  Standard Class  Home Office  United States     Providence  Rhode Island
# 8488    Second Class     Consumer  United States      Arlington      Virginia
# 509   Standard Class     Consumer  United States        Atlanta       Georgia
# 2623     First Class  Home Office  United States  New York City      New York
# 4098  Standard Class     Consumer  United States    Minneapolis     Minnesota
# 9039  Standard Class     Consumer  United States        Detroit      Michigan
# 4190  Standard Class     Consumer  United States         Newark      Delaware
# 8153     First Class     Consumer  United States        Seattle    Washington
# 6826  Standard Class    Corporate  United States      Lafayette       Indiana
#
#       Postal Code   Region         Category Sub-Category      Sales  Quantity  \
# ...

# %% [markdown]
# Top 10 losses

# %%
data[data['Profit']<0].sort_values(by='Profit').tail(10)
# Out:
#            Ship Mode      Segment        Country          City         State  \
# 5091  Standard Class     Consumer  United States      Loveland      Colorado
# 6084  Standard Class     Consumer  United States       Houston         Texas
# 4711        Same Day     Consumer  United States  Philadelphia  Pennsylvania
# 3138  Standard Class  Home Office  United States        Dallas         Texas
# 1068    Second Class     Consumer  United States   Brownsville         Texas
# 4660  Standard Class     Consumer  United States  Philadelphia  Pennsylvania
# 7413  Standard Class  Home Office  United States        Tigard        Oregon
# 1566     First Class     Consumer  United States         Allen         Texas
# 1496  Standard Class     Consumer  United States       Coppell         Texas
# 3228     First Class    Corporate  United States         Tempe       Arizona
#
#       Postal Code   Region         Category Sub-Category   Sales  Quantity  \
# ...

# %% [markdown]
# Effect of subcategories of the Profit

# %%
subcategory=data.groupby(['Category','Sub-Category']).mean()
subcategory
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\943719196.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   subcategory=data.groupby(['Category','Sub-Category']).mean()
#                                Postal Code        Sales  Quantity  Discount  \
# Category        Sub-Category
# Furniture       Bookcases     56015.521930   503.859633  3.807018  0.211140
#                 Chairs        56622.737439   532.332420  3.818476  0.170178
#                 Furnishings   54211.525601    95.825668  3.723093  0.138349
#                 Tables        58331.749216   648.794771  3.890282  0.261285
# Office Supplies Appliances    54185.703863   230.755710  3.710300  0.166524
#                 Art           54434.243719    34.068834  3.768844  0.074874
# ...

# %% [markdown]
# How much each sub-category is discounted ?

# %%
fig=plt.figure(figsize=(10,8))
sub=data.groupby(['Sub-Category']).mean().reset_index().sort_values(by='Discount',ascending=False)
plt.bar(sub['Sub-Category'],sub['Discount'],width=0.3,color='red')
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\3801245533.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sub=data.groupby(['Sub-Category']).mean().reset_index().sort_values(by='Discount',ascending=False)

# %%
sub
# Out:
#    Sub-Category   Postal Code        Sales  Quantity  Discount      Profit
# 3       Binders  54908.994091   133.560560  3.922521  0.372292   19.843574
# 11     Machines  55344.939130  1645.553313  3.826087  0.306087   29.432669
# 16       Tables  58331.749216   648.794771  3.890282  0.261285  -55.565771
# 4     Bookcases  56015.521930   503.859633  3.807018  0.211140  -15.230509
# 5        Chairs  56622.737439   532.332420  3.818476  0.170178   43.095894
# 1    Appliances  54185.703863   230.755710  3.710300  0.166524   38.922758
# 6       Copiers  56962.897059  2198.941618  3.441176  0.161765  817.909190
# 13       Phones  53877.587177   371.211534  3.699663  0.154556   50.073938
# 9   Furnishings  54211.525601    95.825668  3.723093  0.138349   13.645918
# 8     Fasteners  57631.626728    13.936774  4.211982  0.082028    4.375660
# 7     Envelopes  52463.507874    64.867724  3.566929  0.080315   27.418019
# ...

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\2246898758.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# FURNITURE

# %%
figure,axis = plt.subplots(1,2,figsize=(16,8))
category=data.groupby(['Category','Sub-Category']).mean().reset_index()
subcategory=category[category['Category']=='Furniture']
axis[0].bar(subcategory['Sub-Category'],subcategory['Profit'],width=0.2)
axis[0].set_title('Profit made in each sub-category in furniture')
axis[0].axhline(0,color='black')
axis[1].bar(subcategory['Sub-Category'],subcategory['Sales'],width=0.2,color='red')
axis[1].set_title('Sales made in each sub-category in furniture')
plt.show()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\3265336517.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   category=data.groupby(['Category','Sub-Category']).mean().reset_index()

# %%
subcategory.iloc[:,1:]
# Out:
#   Sub-Category   Postal Code       Sales  Quantity  Discount     Profit
# 0    Bookcases  56015.521930  503.859633  3.807018  0.211140 -15.230509
# 1       Chairs  56622.737439  532.332420  3.818476  0.170178  43.095894
# 2  Furnishings  54211.525601   95.825668  3.723093  0.138349  13.645918
# 3       Tables  58331.749216  648.794771  3.890282  0.261285 -55.565771

# %% [markdown]
# We can see that the biggest loss is in the sub-category of 'tables' but it's also the most sold.So we can maybe minimize this loss by redducing the discount.

# %% [markdown]
# TECHNOLOGY

# %%
figure,axis = plt.subplots(1,2,figsize=(16,8))
category=data.groupby(['Category','Sub-Category']).mean().reset_index()
subcategory=category[category['Category']=='Technology']
axis[0].bar(subcategory['Sub-Category'],subcategory['Profit'],width=0.2)
axis[0].set_title('Profit made in each sub-category in Technology')
axis[0].axhline(0,color='black')
axis[1].bar(subcategory['Sub-Category'],subcategory['Sales'],width=0.2,color='red')
axis[1].set_title('Sales made in each sub-category in Technology')
plt.show()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\4222798651.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   category=data.groupby(['Category','Sub-Category']).mean().reset_index()

# %%
subcategory.iloc[:,1:]
# Out:
#    Sub-Category   Postal Code        Sales  Quantity  Discount      Profit
# 13  Accessories  57378.624516   215.974604  3.840000  0.078452   54.111788
# 14      Copiers  56962.897059  2198.941618  3.441176  0.161765  817.909190
# 15     Machines  55344.939130  1645.553313  3.826087  0.306087   29.432669
# 16       Phones  53877.587177   371.211534  3.699663  0.154556   50.073938

# %% [markdown]
# The highest profit is in the 'Copiers' sub-category.

# %% [markdown]
# OFFICE SUPLIES

# %%
figure,axis = plt.subplots(1,2,figsize=(16,8))
category=data.groupby(['Category','Sub-Category']).mean().reset_index()
subcategory=category[category['Category']=='Office Supplies']
axis[0].bar(subcategory['Sub-Category'],subcategory['Profit'],width=0.2)
axis[0].set_title('Profit made in each sub-category in Office Suplies')
axis[0].axhline(0,color='black')
axis[1].bar(subcategory['Sub-Category'],subcategory['Sales'],width=0.2,color='red')
axis[1].set_title('Sales made in each sub-category in Office Supplies')
plt.show()
# Out:
# C:\Users\nawre\AppData\Local\Temp\ipykernel_103092\1516549399.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   category=data.groupby(['Category','Sub-Category']).mean().reset_index()

# %%
subcategory.iloc[:,1:]
# Out:
#    Sub-Category   Postal Code       Sales  Quantity  Discount     Profit
# 4    Appliances  54185.703863  230.755710  3.710300  0.166524  38.922758
# 5           Art  54434.243719   34.068834  3.768844  0.074874   8.200737
# 6       Binders  54908.994091  133.560560  3.922521  0.372292  19.843574
# 7     Envelopes  52463.507874   64.867724  3.566929  0.080315  27.418019
# 8     Fasteners  57631.626728   13.936774  4.211982  0.082028   4.375660
# 9        Labels  53716.991758   34.303055  3.846154  0.068681  15.236962
# 10        Paper  55692.862044   57.284092  3.779562  0.074891  24.856620
# 11      Storage  54667.517730  264.590553  3.732861  0.074704  25.152277
# 12     Supplies  55966.094737  245.650200  3.405263  0.076842  -6.258418

# %% [markdown]
# The 'Supplies' have the highest value of loss and 'Appliances' have the highest profit with good sales as well.
